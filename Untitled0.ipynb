# %%
cube=0;
found=False;
for i in range(cube+1):

  if i>0:
   if i**3==cube:
    print("the cube root is", i)
    found= True


if not found and i>0:
   print("number is not a perfect cube")

if i==0:
     print (f"the number is zero {234}")
# Out:
# the number is zero 234

# %%
first_name= input("type your first name ")
last_name= input('type your last name ')
print (f"hello {first_name} {last_name}")
# Out:
# type your first name Mohammad
# type your last name Sohaib
# hello Mohammad Sohaib

# %%
number1= int(input("what do you want to calculate"))
symbol= input("write symbol")
number2= int(input("what do you want to calculate"))
if symbol=="+":
  print(f"your answer is({number1 + number2})")
elif symbol=="-":
    print(f"your answer is({number1 - number2})")
elif symbol=="x":
    print(f"your answer is({number1 * number2})")
elif symbol=="/":
    print(f"your answer is({number1 / number2})")
else:
  print("retry")
# Out:
# what do you want to calculate6
# write symbol//
# what do you want to calculate7
# retry

# %%
num1=12;
num2='';
while num1>0:
 remainder= num1 % 2;
 num1=num1//2;
 num2=str(remainder)+num2
 print(num2)
# Out:
# 0
# 00
# 100
# 1100

# %%
num= input('Type a number');
print(5*num)
num2=int(input("type a number"))
print (5*num2)
# Out:
# Type a number3
# 33333
# type a number3
# 15

# %%
n=0;
where= input("whereyou want  to go, left or right ")
while where=="right":

  n=n+1
  if n>2:
    print("(;)")
  where= input("whereyou want  to go, left or right ")
print("you get out  of forest")
# Out:
# whereyou want  to go, left or right right
# whereyou want  to go, left or right right
# whereyou want  to go, left or right right
# (;)
# whereyou want  to go, left or right left
# you get out  of forest
